# %% [markdown]
# FINANZAS GRAFICOS DESCRIPTIVOS

# %% [markdown]
# CARGO MEDIANTE PANDAS LOS DATOS FINANCIEROS

# %%
import pandas as pd
import yfinance as yf

# Especifica los tickers de las acciones que deseas obtener
tickers = ['FTNT']

# Define el rango de fechas que deseas obtener
start_date = '2020-01-01'
end_date = '2024-04-10'

# Descarga los datos utilizando la función yf.download de yfinance
stock_data1 = yf.download(tickers, start=start_date, end=end_date)

# Visualiza los primeros registros del DataFrame resultante
print(stock_data1.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-01-02  21.520000  22.058001  21.476000  21.936001  21.936001  5541000
# 2020-01-03  21.684000  22.306000  21.620001  22.242001  22.242001  6641000
# 2020-01-06  22.122000  22.472000  21.906000  22.400000  22.400000  7369000
# 2020-01-07  22.466000  22.502001  22.214001  22.378000  22.378000  3796500
# 2020-01-08  22.389999  22.879999  22.360001  22.733999  22.733999  6953000

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
# Note: you may need to restart the kernel to use updated packages.  Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
#
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.8 kB 3.1 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/162.8 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.21 in c:\python\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.4-cp312-cp312-win_amd64.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.7/7.7 MB 13.9 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/7.7 MB 23.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/7.7 MB 22.9 MB/s eta 0:00:01
#    --------------------- ------------------ 4.1/7.7 MB 23.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.7 MB 24.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.7 MB 27.7 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 15.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    -------------------------------------- - 184.3/189.9 kB ? eta -:--:--
#    -------------------------------------- - 184.3/189.9 kB ? eta -:--:--
#    ---------------------------------------- 189.9/189.9 kB 1.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.2 MB 50.9 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 46.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 15.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 738.1 kB/s eta 0:00:00
# Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------------------------------- -- 2.4/2.5 MB 77.0 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 54.8 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 54.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 16.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------  102.4/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 pillow-10.3.0 pyparsing-3.1.2

# %% [markdown]
# CREACION DE LA GRAFICA POR MATPLOTLIB (para la acción)

# %% [markdown]
# Este grafico representara el comportamiento de los precios de cierre para las acciones para lo que permitira tener una idea de que tanto varia

# %%
import matplotlib.pyplot as plt

# Grafica la serie de precios
stock_data1['Adj Close'].plot(figsize=(10, 6), title='Precios Fortinet')
plt.xlabel('Fecha')
plt.ylabel('Precio (USD)')
plt.grid(True)
plt.show()

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.37-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\python\lib\site-packages (from yfinance) (2.2.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\python\lib\site-packages (from yfinance) (1.26.4)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pytz>=2022.5 in c:\python\lib\site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.1.tar.gz (315 kB)
#      ---------------------------------------- 0.0/315.2 kB ? eta -:--:--
#      ------------------------------------  307.2/315.2 kB 18.6 MB/s eta 0:00:01
#      ------------------------------------  307.2/315.2 kB 18.6 MB/s eta 0:00:01
#      ------------------------------------  307.2/315.2 kB 18.6 MB/s eta 0:00:01
#      ------------------------------------  307.2/315.2 kB 18.6 MB/s eta 0:00:01
#      -------------------------------------- 315.2/315.2 kB 1.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      -------- ------------------------------- 0.6/3.0 MB 18.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.6/3.0 MB 24.0 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 27.0 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 27.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 13.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six>=1.9 in c:\users\acer\appdata\roaming\python\python312\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.31->yfinance)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/73.0 kB ? eta -:--:--
#    ---------------------------------------  71.7/73.0 kB ? eta -:--:--
#    ---------------------------------------- 73.0/73.0 kB 996.1 kB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -------------------------------------- - 143.4/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 2.2 MB/s eta 0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ------------------------------------ --- 102.4/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 2.2 MB/s eta 0:00:00
# Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------- ----------------- 2.1/3.8 MB 34.2 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 48.7 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 48.7 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 48.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 18.8 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 830.7 kB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.8 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB 1.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    -------------------------------------- 100.4/100.4 kB 338.9 kB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------  61.4/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 1.1 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ------------------------------------- -- 112.6/121.1 kB ? eta -:--:--
#    ------------------------------------- -- 112.6/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 1.4 MB/s eta 0:00:00
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: frozendict, peewee
#   Building wheel for frozendict (pyproject.toml): started
#   Building wheel for frozendict (pyproject.toml): finished with status 'done'
#   Created wheel for frozendict: filename=frozendict-2.4.1-cp312-cp312-win_amd64.whl size=15540 sha256=32eb69693338dd8d48c85c81bedb8be7328ce5475282ae82417e04e3526be6aa
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\a1\2a\ed\313e8c375a307e932fb57a79e12194d3e0fa64748459a76094
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.1-py3-none-any.whl size=136948 sha256=04dbbaf7c31412036442d0c68adbed3452230d77878830a171b82bd02abae340
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\fe\58\f4\132ded03aa364dd5d2bbc2d02e1c2074a9b5012776d15fc2dc
# Successfully built frozendict peewee
# Installing collected packages: webencodings, peewee, multitasking, appdirs, urllib3, soupsieve, lxml, idna, html5lib, frozendict, charset-normalizer, certifi, requests, beautifulsoup4, yfinance
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.3 certifi-2024.2.2 charset-normalizer-3.3.2 frozendict-2.4.1 html5lib-1.1 idna-3.6 lxml-5.2.1 multitasking-0.0.11 peewee-3.17.1 requests-2.31.0 soupsieve-2.5 urllib3-2.2.1 webencodings-0.5.1 yfinance-0.2.37
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# PARA EL ANALISIS DE LA SERIE ES NECESARIO LA GRAFICACION DEL MERCADO PARA TENER UN PUNTO DE REFERENCIA

# %% [markdown]
# Tambien se considera bastante util el general la graficacion del mercado dado que este es el punto de referencia para posteriormente comparar los niveles de riesgo, el sharpe entre otros.

# %%
import pandas as pd
import yfinance as yf

# Especifica los tickers de las acciones que deseas obtener
tickers = ['NDAQ']

# Define el rango de fechas que deseas obtener
start_date = '2020-01-01'
end_date = '2024-04-10'

# Descarga los datos utilizando la función yf.download de yfinance
stock_data = yf.download(tickers, start=start_date, end=end_date)

# Visualiza los primeros registros del DataFrame resultante
print(stock_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-01-02  35.753334  35.986668  35.723331  35.939999  33.784290  1923900
# 2020-01-03  35.660000  36.160000  35.580002  36.093334  33.928440  2164800
# 2020-01-06  35.930000  36.086666  35.630001  36.070000  33.906498  2155200
# 2020-01-07  36.000000  36.086666  35.463333  35.473331  33.345619  1673100
# 2020-01-08  35.503334  35.653332  35.080002  35.276669  33.160751  3501000

# %%
import matplotlib.pyplot as plt

# Grafica la serie de precios
stock_data['Adj Close'].plot(figsize=(10, 6), title='Precios Mercado ')
plt.xlabel('Fecha')
plt.ylabel('Precio (USD)')
plt.grid(True)
plt.show()

# %%
# Calcula la primera diferencia de los precios ajustados al cierre (Adj Close) de cada acción
stock_data_diff = stock_data1.diff()

# Elimina la primera fila que contendrá NaN ya que no hay un valor anterior para calcular la diferencia
stock_data_diff = stock_data_diff.dropna()

# Muestra los primeros registros del DataFrame resultante
print(stock_data_diff.head())
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-01-03  0.164000  0.247999  0.144001  0.306000   0.306000  1100000.0
# 2020-01-06  0.438000  0.166000  0.285999  0.157999   0.157999   728000.0
# 2020-01-07  0.344000  0.030001  0.308001 -0.021999  -0.021999 -3572500.0
# 2020-01-08 -0.076000  0.377998  0.146000  0.355999   0.355999  3156500.0
# 2020-01-09  0.612001  0.276001  0.327999  0.162001   0.162001 -1476500.0

# %%
pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\python\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\python\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/294.9 kB ? eta -:--:--
#    --------- ----------------------------- 71.7/294.9 kB 787.7 kB/s eta 0:00:01
#    -------------------- ------------------- 153.6/294.9 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/294.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 701.2 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Grafica la primera diferencia de los precios ajustados al cierre
plt.figure(figsize=(10, 6))
sns.lineplot(data=stock_data_diff['Adj Close'])
plt.title('Primera Diferencia de Precios de Acciones')
plt.xlabel('Fecha')
plt.ylabel('Primera Diferencia de Precio (USD)')
plt.show()

# %% [markdown]
# Para la modelacion de la serie financiera necesitamos que la serie tenga un componente estacionario ademas de que los datos con los que se va atrabajar deberian ser los rendimientos y no tanto los precios para lo que se saca una primera diferencia a partir de los precios y se genera los rendimientos. Esta grafica nos permite observar que la serie es estable en media para el caso de la acción de la empresa FORTINET dedicada al desarrollo y comercializacion de software

# %%
# Calcula la primera diferencia de los precios ajustados al cierre (Adj Close) de cada acción
stock_data_diff1 = stock_data.diff()

# Elimina la primera fila que contendrá NaN ya que no hay un valor anterior para calcular la diferencia
stock_data_diff1 = stock_data_diff1.dropna()

# Muestra los primeros registros del DataFrame resultante
print(stock_data_diff1.head())
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-01-03 -0.093334  0.173332 -0.143330  0.153336   0.144150   240900.0
# 2020-01-06  0.270000 -0.073334  0.049999 -0.023335  -0.021942    -9600.0
# 2020-01-07  0.070000  0.000000 -0.166668 -0.596668  -0.560879  -482100.0
# 2020-01-08 -0.496666 -0.433334 -0.383331 -0.196663  -0.184868  1827900.0
# 2020-01-09 -0.080002  0.310001  0.250000  0.506664   0.476280 -1911000.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Grafica la primera diferencia de los precios ajustados al cierre
plt.figure(figsize=(10, 6))
sns.lineplot(data=stock_data_diff1['Adj Close'])
plt.title('Primera Diferencia de Precios de Mercado')
plt.xlabel('Fecha')
plt.ylabel('Primera Diferencia de Precio (USD)')
plt.show()
